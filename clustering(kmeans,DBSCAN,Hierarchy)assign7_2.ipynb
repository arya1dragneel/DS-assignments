# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Import Dataset
airline=pd.read_csv('/content/EastWestAirlines.csv')
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline2=airline.drop(['ID#'],axis=1)
airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
# Normalize heterogenous numerical data by using Standard Scaler
airline2_norm=StandardScaler().fit_transform(airline2)

# %%
# Use Elbow Graph to find optimum number of  clusters (K value) from K values range
# The K-means algorithm aims to choose centroids that minimise the inertia, or within-cluster sum-of-squares criterion WCSS
# random state can be anything from 0 to 42, but the same number to be used everytime,so that the results don't change.

# %%
# within-cluster sum-of-squares criterion
wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,random_state=2)
    kmeans.fit(airline2_norm)
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Plot K values range vs WCSS to get Elbow graph for choosing K (no. of clusters)
plt.plot(range(1,11),wcss)
plt.title('Elbow Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Cluster algorithm using K=4(build cluster algorithm using k4)
clusters4=KMeans(4,random_state=30).fit(airline2_norm)
clusters4
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=30)

# %%
clusters4.labels_
# Out:
# array([0, 0, 0, ..., 3, 0, 0], dtype=int32)

# %%
# Assign clusters to the data set
airline4=airline2.copy()
airline4['clusters4id']=clusters4.labels_
airline4
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Compute the centroids for K=4 clusters with 11 variables
clusters4.cluster_centers_
# Out:
# array([[-0.29584258, -0.0603903 , -0.60911906,  0.03222463, -0.06075301,
#         -0.51562007, -0.48778976, -0.18468409, -0.19727389, -0.2065444 ,
#         -0.34933297],
#        [ 0.63971926, -0.08443292,  1.0220844 , -0.09824189, 15.64629931,
#          3.17969131,  1.71461374,  0.03329269,  0.05969539,  0.23987261,
#          0.33752735],
#        [ 1.19916278,  0.8413837 ,  0.07934291,  0.15576844, -0.06276658,
#          0.61091878,  1.63802866,  3.57547132,  3.86140846,  0.28565421,
#          0.91563614],
#        [ 0.43059508,  0.0158422 ,  1.18872871, -0.08236624, -0.05476264,
#          0.91116803,  0.74463543, -0.08026444, -0.09129375,  0.37198921,
#          0.57588937]])

# %%
# Group data by Clusters (K=4)
airline4.groupby('clusters4id').agg(['mean']).reset_index()
# Out:
#   clusters4id        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                         mean        mean      mean      mean      mean
# 0           0   43828.396152   97.283863  1.223007  1.019238  1.000393
# 1           1  138061.400000   78.800000  3.466667  1.000000  4.066667
# 2           2  194432.643750  794.981250  2.168750  1.037500  1.000000
# 3           3  117087.423649  156.736883  3.697729  1.002349  1.001566
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0   4707.805654    6.926973        201.254417        0.624656
# 1  93927.866667   28.066667        506.666667        1.600000
# 2  31897.281250   27.331250       5465.837500       16.018750
# 3  39200.451057   18.761942        348.499608        1.029757
#
#   Days_since_enroll    Award?
#                mean      mean
# 0       3693.855124  0.201413
# 1       4613.866667  0.533333
# 2       4708.400000  0.812500
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))
plt.scatter(airline4['clusters4id'],airline4['Balance'], c=clusters4.labels_)

# %%
# Cluster algorithm using K=5
clusters5=KMeans(5,random_state=30).fit(airline2_norm)
clusters5
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=30)

# %%
clusters5.labels_
# Out:
# array([0, 0, 0, ..., 3, 0, 0], dtype=int32)

# %%
# Assign clusters to the data set
airline5=airline2.copy()
airline5['clusters5id']=clusters5.labels_
airline5
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Compute the centroids for K=5 clusters with 11 variables
clusters5.cluster_centers_
# Out:
# array([[-2.97441370e-01, -6.26013958e-02, -6.09944285e-01,
#         -9.82418871e-02, -6.07159307e-02, -5.21330789e-01,
#         -5.01454441e-01, -1.87180704e-01, -1.99831577e-01,
#         -2.10475283e-01, -3.52420208e-01],
#        [ 1.14970340e+00,  1.06407580e+00,  1.02900923e-01,
#         -9.82418871e-02, -6.27665798e-02,  5.78252911e-01,
#          1.52034538e+00,  3.44900129e+00,  3.66768718e+00,
#          2.64756357e-01,  8.99553448e-01],
#        [ 6.39719256e-01, -8.44329231e-02,  1.02208440e+00,
#         -9.82418871e-02,  1.56462993e+01,  3.17969131e+00,
#          1.71461374e+00,  3.32926913e-02,  5.96953922e-02,
#          2.39872612e-01,  3.37527346e-01],
#        [ 4.24748143e-01, -1.21396375e-02,  1.19282031e+00,
#         -9.82418871e-02, -5.47249449e-02,  9.11488076e-01,
#          7.40508649e-01, -9.38523027e-02, -1.02849450e-01,
#          3.77190968e-01,  5.65958814e-01],
#        [-4.68896637e-02, -1.56235600e-01, -6.68227273e-01,
# ...

# %%
# Group data by Clusters (K=5)
airline5.groupby('clusters5id').agg(['mean']).reset_index()
# Out:
#   clusters5id        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                         mean        mean      mean      mean      mean
# 0           0   43669.876000   95.611600  1.221200  1.000000  1.000400
# 1           1  189448.964497  967.248521  2.201183  1.000000  1.000000
# 2           2  138061.400000   78.800000  3.466667  1.000000  4.066667
# 3           3  116436.737421  134.935535  3.702830  1.000000  1.001572
# 4           4   68876.581395   23.255814  1.139535  2.348837  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0   4568.151200    6.791600        197.838000        0.615200
# 1  31108.467456   26.201183       5288.775148       15.284024
# 2  93927.866667   28.066667        506.666667        1.600000
# 3  39185.495283   18.721698        329.176101        0.985063
# 4  14689.837209   17.534884        582.627907        2.209302
#
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))
plt.scatter(airline5['clusters5id'],airline5['Balance'], c=clusters5.labels_)

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
# Import Datase
df=pd.read_csv('/content/EastWestAirlines.csv')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
#dbscan expects data in the form of an array /numpy representation
array=df.values
array
# Out:
# array([[    1, 28143,     0, ...,     0,  7000,     0],
#        [    2, 19244,     0, ...,     0,  6968,     0],
#        [    3, 41354,     0, ...,     0,  7034,     0],
#        ...,
#        [ 4019, 73597,     0, ...,     0,  1402,     1],
#        [ 4020, 54899,     0, ...,     1,  1401,     0],
#        [ 4021,  3016,     0, ...,     0,  1398,     0]])

# %%
#stanadardiize the data
stdscaler=StandardScaler().fit(array)
x=stdscaler.transform(array)

# %%
#min=D+1 where D is the number of columns
#as we decrease eps, more outliers are formed as radius decreases
dbscan=DBSCAN(eps=1.2,min_samples=5)
dbscan.fit(x)
# Out:
# DBSCAN(eps=1.2)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
clust=pd.DataFrame(dbscan.labels_,columns=['cluster'])
clust
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 3994        1
# 3995        1
# 3996        1
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
crime_data1=pd.concat([df,clust],axis=1)
crime_data1.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    cluster
# 0        0
# 1        0
# 2        0
# ...

# %%
crime_data1.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster          ID#        Balance   Qual_miles cc1_miles cc2_miles  \
#                   mean           mean         mean      mean      mean
# 0      -1  1715.297131  188656.038934  1046.106557  2.739754  1.090164
# 1       0  2176.541897   54493.721395     6.515951  1.671629  1.000000
# 2       1  1790.462081   64659.493827    18.899471  2.595238  1.000000
# 3       2  2484.714286   34032.142857     0.000000  1.000000  2.000000
# 4       3  3164.833333   29375.583333  2421.916667  1.000000  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0   1.10041  40977.286885   22.950820       2364.116803        6.811475
# 1   1.00000   9280.949383    8.579753        147.383241        0.454700
# 2   1.00000  23461.631393   13.048501        297.311287        0.960317
# 3   1.00000   8312.500000   12.285714         57.142857        0.357143
# ...

# %%
crime_data1['cluster'].nunique()
# Out:
# 5

# %%
print(crime_data1['cluster'].unique())
# Out:
# [ 0  1 -1  2  3]

# %%
#plot cluster
plt.figure(figsize=(10,7))
plt.scatter(crime_data1['cluster'],crime_data1['Balance'],c=dbscan.labels_)

# %%
#silhoutte score
import sklearn
round(sklearn.metrics.silhouette_score(x,dbscan.labels_),5)
# Out:
# 0.17305

# %% [markdown]
# # Hierarchy

# %%
import scipy.cluster.hierarchy as sch
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering

# %%
crime_data=pd.read_csv("/content/EastWestAirlines.csv")
crime_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
crime_data.shape
# Out:
# (3999, 12)

# %%
crime_data.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
crime_data.hist()
# Out:
# array([[<Axes: title={'center': 'ID#'}>,
#         <Axes: title={'center': 'Balance'}>,
#         <Axes: title={'center': 'Qual_miles'}>],
#        [<Axes: title={'center': 'cc1_miles'}>,
#         <Axes: title={'center': 'cc2_miles'}>,
#         <Axes: title={'center': 'cc3_miles'}>],
#        [<Axes: title={'center': 'Bonus_miles'}>,
#         <Axes: title={'center': 'Bonus_trans'}>,
#         <Axes: title={'center': 'Flight_miles_12mo'}>],
#        [<Axes: title={'center': 'Flight_trans_12'}>,
#         <Axes: title={'center': 'Days_since_enroll'}>,
#         <Axes: title={'center': 'Award?'}>]], dtype=object)

# %%
sns.pairplot(crime_data1,diag_kind='kde')

# %%
crime_data1.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?', 'cluster'],
#       dtype='object')

# %%
crime_data1=crime_data.rename({'Award?':'Award','ID#':'ID'},axis=1)
crime_data1.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
plt.figure(figsize=(10,5))
plt.scatter(crime_data1.ID,crime_data1.Balance,color='r')
plt.scatter(crime_data1.ID,crime_data1.Qual_miles,color='g')
plt.scatter(crime_data1.ID,crime_data1.cc1_miles,color='b')
plt.scatter(crime_data1.ID,crime_data1.cc2_miles,color='y')
plt.scatter(crime_data1.ID,crime_data1.cc3_miles,color='r')
plt.scatter(crime_data1.ID,crime_data1.Bonus_miles,color='y')
plt.scatter(crime_data1.ID,crime_data1.Bonus_trans,color='b')
plt.scatter(crime_data1.ID,crime_data1.Flight_miles_12mo,color='g')
plt.scatter(crime_data1.ID,crime_data1.Flight_trans_12,color='b')
plt.scatter(crime_data1.ID,crime_data1.Days_since_enroll,color='g')
plt.scatter(crime_data1.ID,crime_data1.Award,color='r')
plt.xlabel('ID')
plt.ylabel('RATE')
plt.show()

# %%
#Data normalisation
#Defining the normaliation function
def normalf(i):
  x=(i-i.min())/(i.max()-i.min())
  return(x)

# %%
#normalize the dataframe
crime_data_normal=normalf(crime_data1.iloc[:,1:])

# %%
crime_data_normal
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# create a dendogram
#plotting the pendogram-eard method
plt.figure(figsize=(12,6))
dendogram=sch.dendrogram(sch.linkage(crime_data_normal,method='ward'))

# %%
#fit and predict
#specifying hierarchical clustering ,clusters as 3(we are considering n of clusteres=3)
hc=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', n_clusters=5)

# %%
#prediction - there is no centroid in agglomerative options
y_hc=hc.fit_predict(crime_data_normal)
y_hc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([1, 1, 1, ..., 0, 4, 4])

# %%
#clusters are formed
# creating new dataframe column are clusters
clusters=pd.DataFrame(y_hc,columns=['clusters'])
crime_data1['cluster']=clusters

# %%
crime_data1
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
crime_data1.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster           ID        Balance  Qual_miles cc1_miles cc2_miles  \
#                   mean           mean        mean      mean      mean
# 0       0  1889.710359   79848.233615  285.097252  1.699789  1.024313
# 1       1  1567.278932   43313.653808   21.506429  1.000000  1.033630
# 2       2  1877.870050  106221.111386  161.262376  3.198020  1.001238
# 3       3  1490.760748  127475.028037  160.801869  4.362617  1.000000
# 4       4  3390.846924   30013.416309   98.054363  1.000000  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000000  12079.774841   12.133192        781.939746        2.369979
# 1  1.000989   2562.614243    5.474777        169.510386        0.523244
# 2  1.025990  26458.257426   16.363861        198.733911        0.558168
# 3  1.050467  58656.919626   22.235514        991.110280        3.005607
# ...

# %%
crime_data1['cluster'].value_counts()
# Out:
# 1    1011
# 0     946
# 2     808
# 4     699
# 3     535
# Name: cluster, dtype: int64

# %%
#plot clusters
plt.figure(figsize=(10,7))
plt.scatter(crime_data1['cluster'],crime_data1['Balance'],c=hc.labels_)

# %%
#5 cluster form
